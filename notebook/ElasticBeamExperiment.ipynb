# %%
from IPython.display import YouTubeVideo
# Experiment: Measure a curvature of a simply supported beam and relate that measured curvature to the bending moments and displacement of the beam. 
# Video credit: Prof Fehmi Cirak.
YouTubeVideo('BcCnCaeubQ8')

# %%
from IPython.display import YouTubeVideo
# Experiment: Measure a curvature of a simply supported beam and relate that measured curvature to the bending moments and displacement of the beam (Slides). 
# Video credit: Prof Fehmi Cirak.
YouTubeVideo('oL4i8tfyC2Y')
